# %%
import time
import matplotlib.pyplot as plt
import numpy as np
import tqdm

from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# ### train size

# %%
num_features = 10
timing_dict = dict()
for size in tqdm.tqdm(np.arange(1000, 100001, 1000)):
    X = np.random.uniform(size=(size, num_features))
    y = np.random.uniform(size=size)
    model = GradientBoostingRegressor()
    t_start = time.time()
    model.fit(X, y)
    t_duration = time.time() - t_start
    timing_dict[size] = t_duration

# %%
plt.plot(timing_dict.keys(), timing_dict.values())
plt.grid()
plt.xlabel('train_size')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %% [markdown]
# ### num_features

# %%
size = 5000
timing_dict2 = dict()
for num_features in tqdm.tqdm(np.arange(1, 101, 10)):
    X = np.random.uniform(size=(size, num_features))
    y = np.random.uniform(size=size)
    model = GradientBoostingRegressor()
    t_start = time.time()
    model.fit(X, y)
    t_duration = time.time() - t_start
    timing_dict2[num_features] = t_duration

# %%
plt.plot(timing_dict2.keys(), timing_dict2.values())
plt.grid()
plt.xlabel('num_features')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %% [markdown]
# ### max_depth

# %%
size = 10000
num_features = 10
timing_dict3 = dict()
for depth in tqdm.tqdm(np.arange(1, 25, 3)):
    X = np.random.uniform(size=(size, num_features))
    y = np.random.uniform(size=size)
    model = GradientBoostingRegressor(max_depth=depth)
    t_start = time.time()
    model.fit(X, y)
    t_duration = time.time() - t_start
    timing_dict3[depth] = t_duration
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:03,  1.90it/s]
#  25%|██▌       | 2/8 [00:01<00:04,  1.30it/s]
#  38%|███▊      | 3/8 [00:04<00:06,  1.33s/it]
#  50%|█████     | 4/8 [00:09<00:09,  2.31s/it]
#  62%|██████▎   | 5/8 [00:16<00:11,  3.83s/it]
#  75%|███████▌  | 6/8 [00:31<00:14,  7.25s/it]
#  88%|████████▊ | 7/8 [00:56<00:12, 12.59s/it]
# 100%|██████████| 8/8 [01:27<00:00, 17.99s/it]

# %%
plt.plot(timing_dict3.keys(), timing_dict3.values())
plt.grid()
plt.xlabel('max_depth')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %% [markdown]
# ### num_estimatos

# %%
size = 5000
num_features = 10
timing_dict4 = dict()
for n_estimators in tqdm.tqdm(np.arange(100, 1001, 100)):
    X = np.random.uniform(size=(size, num_features))
    y = np.random.uniform(size=size)
    model = GradientBoostingRegressor(n_estimators=n_estimators)
    t_start = time.time()
    model.fit(X, y)
    t_duration = time.time() - t_start
    timing_dict4[n_estimators] = t_duration
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:05,  1.75it/s]
#  20%|██        | 2/10 [00:01<00:05,  1.49it/s]
#  30%|███       | 3/10 [00:02<00:05,  1.18it/s]
#  40%|████      | 4/10 [00:04<00:06,  1.14s/it]
#  50%|█████     | 5/10 [00:06<00:07,  1.47s/it]
#  60%|██████    | 6/10 [00:09<00:07,  1.80s/it]
#  70%|███████   | 7/10 [00:12<00:06,  2.23s/it]
#  80%|████████  | 8/10 [00:16<00:05,  2.71s/it]
#  90%|█████████ | 9/10 [00:20<00:03,  3.10s/it]
# 100%|██████████| 10/10 [00:24<00:00,  3.48s/it]

# %%
plt.plot(timing_dict4.keys(), timing_dict4.values())
plt.grid()
plt.xlabel('n_estimators')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')
